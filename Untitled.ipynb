# %%
import librosa
import librosa.display
import numpy as np
import IPython.display as ipd
from utils.aug_utils import mix_db
from utils.prep_utils import loudness_normalize,stft_process

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train = np.load('../eggdata/TrainData/valid_processing_0205.npy',mmap_mode='r')

# %%
x = np.array(train[1][20000:40000].tolist())
y = np.random.normal(size = x.shape)

# x = mix_db(x,y,0)

# %%
plt.plot(x[5000:6000])

# %%
ipd.Audio(x,rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(loudness_normalize(x),rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(x)

# %%
# X = librosa.stft(loudness_normalize(x),n_fft = 512, hop_length = 128, window = 'hann')
X = librosa.stft(x,n_fft = 512, hop_length = 128, window = 'hann')

# %%
librosa.display.specshow(np.log(np.abs(X)+1e-5))

# %%
p = stft_process(X,mask=True).astype(np.float32)

# %%
# librosa.display.specshow(p[1,:,:]*p[2,:,:])

# %%
librosa.display.specshow(p[0,:,:]*p[2,:,:])

# %%
recon = librosa.istft(np.exp(p[0,:,:])*p[2,:,:]*(np.cos(p[1,:,:])+1j*np.sin(p[1,:,:])),128,512,length=20000)
plt.plot(recon)

# %%
# Out:
# array([-0.02872473, -0.01604128, -0.02010417, ..., -0.01218295,
#         0.00234461,  0.03475845])

# %%
plt.plot(recon[10000:14000])
plt.plot(x[10000:14000])

# %%
plt.plot(recon-x)
