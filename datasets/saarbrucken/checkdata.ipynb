# %%
import librosa
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
np.array([[]]).shape
# Out:
# (1, 0)

# %%
files = os.listdir('./export/')
print(len(files))
for file in files:
    if(os.stat('./export/'+file).st_size == 0):
        os.remove('./export/'+file)
    
    if 'egg' in file:
        speech = './export/' + file[:-7]+'.wav'
        egg= './export/' + file
    else:
        speech = './export/' + file
        egg = './export/' + file[:-4]+'-egg.wav'
    if not os.path.exists(speech) or not os.path.exists(egg):
        try:
            os.remove(speech)
        except:
            continue
        try:
            os.remove(egg)
        except:
            continue
    if os.stat(egg).st_size != os.stat(speech).st_size:
        print(file)

x ,sr = librosa.load('./export/1215-iau.wav',sr=50000)
y, sr = librosa.load('./export/1215-iau-egg.wav',sr=50000)
# Out:
# 8008
# 1207-iau.wav
# 1215-iau.wav
# 1209-iau.wav
# 1211-iau.wav
# 1216-iau.wav
# 1206-iau.wav
# 1204-iau.wav
# 1205-iau.wav
# 1217-iau.wav
# 1219-iau.wav
# 1238-iau.wav
# 1243-iau.wav
# 1244-iau.wav
# 1234-iau.wav
# 1235-iau.wav
# 1246-iau.wav
# 1237-iau.wav
# 1245-iau.wav
# 1240-iau.wav
# 1241-iau.wav
# 1247-iau.wav
# 1248-iau.wav
# 1249-iau.wav
# 1250-iau.wav
# 1176-iau.wav
# 1177-iau.wav
# 1135-iau.wav
# 1133-iau.wav
# 1134-iau.wav
# 1138-iau.wav
# 1137-iau.wav
# 1139-iau.wav
# 1140-iau.wav
# 1141-iau.wav
# 1142-iau.wav
# 1144-iau.wav
# 1145-iau.wav
# 1146-iau.wav
# 1147-iau.wav
# 1149-iau.wav
# 1150-iau.wav
# 115-iau.wav
# 116-iau.wav
# 117-iau.wav
# 125-iau.wav
# 105-iau.wav
# 108-iau.wav
# 110-iau.wav
# 111-iau.wav
# 1308-iau.wav
# 1320-iau.wav
# 1314-iau.wav
# 1303-iau.wav
# 1302-iau.wav
# 1325-iau.wav
# 1313-iau.wav
# 1301-iau.wav
# 1304-iau.wav
# 1305-iau.wav
# 1306-iau.wav
# 1307-iau.wav
# 1309-iau.wav
# 1310-iau.wav
# 1311-iau.wav
# 1312-iau.wav
# 1322-iau.wav
# 1317-iau.wav
# 1318-iau.wav
# 1323-iau.wav
# 1319-iau.wav
# 1278-iau.wav
# 1276-iau.wav
# 1292-iau.wav
# 1277-iau.wav
# 1293-iau.wav
# 1295-iau.wav
# 1296-iau.wav
# 1297-iau.wav
# 1299-iau.wav
# 1300-iau.wav
# 1109-iau.wav
# 1110-iau.wav
# 1101-iau.wav
# 1102-iau.wav
# 1111-iau.wav
# 1103-iau.wav
# 1104-iau.wav
# 1105-iau.wav
# 1108-iau.wav
# 1113-iau.wav
# 1115-iau.wav
# 1116-iau.wav
# 1117-iau.wav
# 1118-iau.wav
# 1073-iau.wav
# 1074-iau.wav
# 1075-iau.wav
# 1051-iau.wav
# 1056-iau.wav
# 1052-iau.wav
# 1054-iau.wav
# 1055-iau.wav
# 1376-iau.wav
# 1042-iau.wav
# 1043-iau.wav
# 1044-iau.wav
# 1045-iau.wav
# 1046-iau.wav
# 1047-iau.wav
# 1049-iau.wav
# 1050-iau.wav
# 1335-iau.wav
# 1344-iau.wav
# 1346-iau.wav
# 1347-iau.wav
# 1348-iau.wav
# 1349-iau.wav
# 1350-iau.wav
# 1342-iau.wav
# 1331-iau.wav
# 1333-iau.wav
# 1339-iau.wav
# 1332-iau.wav
# 1341-iau.wav
# 1340-iau.wav
# 1326-iau.wav
# 1327-iau.wav
# 1328-iau.wav
# 1329-iau.wav
# 1330-iau.wav
# 1334-iau.wav
# 1336-iau.wav
# 1338-iau.wav
# 1337-iau.wav
# 127-iau.wav
# 132-iau.wav
# 133-iau.wav
# 134-iau.wav
# 135-iau.wav
# 136-iau.wav
# 131-iau.wav
# 1359-iau.wav
# 1356-iau.wav
# 1357-iau.wav
# 1358-iau.wav
# 1360-iau.wav
# 1351-iau.wav
# 1352-iau.wav
# 1353-iau.wav
# 1354-iau.wav
# 1363-iau.wav
# 1361-iau.wav
# 1366-iau.wav
# 1367-iau.wav
# 1368-iau.wav
# 1370-iau.wav
# 1362-iau.wav
# 1371-iau.wav
# 1373-iau.wav
# 1375-iau.wav
# 1374-iau.wav
# 2054-iau.wav
# 2061-iau.wav
# 2055-iau.wav
# 2056-iau.wav
# 2057-iau.wav
# 2058-iau.wav
# 2062-iau.wav
# 2063-iau.wav
# 2066-iau.wav
# 2067-iau.wav
# 2068-iau.wav
# 2069-iau.wav
# 2070-iau.wav
# 2071-iau.wav
# 2072-iau.wav
# 2074-iau.wav
# 2075-iau.wav
# 1269-iau.wav
# 1271-iau.wav
# 1254-iau.wav
# 1262-iau.wav
# 1274-iau.wav
# 1267-iau.wav
# 1251-iau.wav
# 1252-iau.wav
# 1253-iau.wav
# 1255-iau.wav
# 1261-iau.wav
# 1270-iau.wav
# 1256-iau.wav
# 1257-iau.wav
# 1258-iau.wav
# 1259-iau.wav
# 1264-iau.wav
# 1260-iau.wav
# 1265-iau.wav
# 1266-iau.wav
# 1268-iau.wav
# 1272-iau.wav
# 1273-iau.wav
# 1275-iau.wav
# 1078-iau.wav
# 1079-iau.wav
# 1080-iau.wav
# 1082-iau.wav
# 1083-iau.wav
# 1084-iau.wav
# 1085-iau.wav
# 1086-iau.wav
# 1087-iau.wav
# 1090-iau.wav
# 1091-iau.wav
# 1092-iau.wav
# 1093-iau.wav
# 1094-iau.wav
# 1095-iau.wav
# 1096-iau.wav
# 1097-iau.wav
# 1098-iau.wav
# 1099-iau.wav
# 11-iau.wav
# 1100-iau.wav
# 1151-iau.wav
# 1155-iau.wav
# 1156-iau.wav
# 1157-iau.wav
# 1159-iau.wav
# 1160-iau.wav
# 1161-iau.wav
# 1162-iau.wav
# 1163-iau.wav
# 1164-iau.wav
# 1165-iau.wav
# 1166-iau.wav
# 1167-iau.wav
# 1168-iau.wav
# 1170-iau.wav
# 1171-iau.wav
# 1172-iau.wav
# 1173-iau.wav
# 1175-iau.wav
# 13-iau.wav

# %%
print(len(x),len(y))
# Out:
# 327658 131050

# %%
plt.plot(x[100000:110000])
len(x)
# Out:
# 327658

# %%
plt.plot(y[100000:110000])

# %%
def check(drt,file,window,step):
    X,Y = [],[]
    
    print(file)
    x,sr = librosa.load(drt+file,sr=50000)
    y,sr = librosa.load(drt+file[:-4]+'-egg.wav',sr=50000)
    
    print(len(x),len(y))

# %%
print("load saarbrucken data sets")
args = []

files = os.listdir('./export/')
for file in files:
    if 'wav' in file and file[:-4]+'-egg.wav' in files:
        args.append(('./export/',file,512,256))
        
for arg in args:
    check(*arg)
# Out:
# load saarbrucken data sets
# 1207-iau.wav
# 294890 393194
# 1207-phrase.wav
# 75996 75996
# 1215-iau.wav
# 327658 131050
# 1215-phrase.wav
# 70392 70392
# 1214-iau.wav
# RuntimeErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     126     try:
# --> 127         with sf.SoundFile(path) as sf_desc:
#     128             sr_native = sf_desc.samplerate
#
# /opt/conda/lib/python3.7/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     626                                          format, subtype, endian)
# --> 627         self._file = self._open(file, mode_int, closefd)
#     628         if set(mode).issuperset('r+') and self.seekable():
#
# /opt/conda/lib/python3.7/site-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1181         _error_check(_snd.sf_error(file_ptr),
# -> 1182                      "Error opening {0!r}: ".format(self.name))
#    1183         if mode_int == _snd.SFM_WRITE:
#
# /opt/conda/lib/python3.7/site-packages/soundfile.py in _error_check(err, prefix)
#    1354         err_str = _snd.sf_error_number(err)
# -> 1355         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1356
#
# RuntimeError: Error opening './export/1214-iau-egg.wav': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# EOFErrorTraceback (most recent call last)
# <ipython-input-10-90696eb6233e> in <module>
#       8
#       9 for arg in args:
# ---> 10     check(*arg)
#
# <ipython-input-9-5d315fb92d72> in check(drt, file, window, step)
#       4     print(file)
#       5     x,sr = librosa.load(drt+file,sr=50000)
# ----> 6     y,sr = librosa.load(drt+file[:-4]+'-egg.wav',sr=50000)
#       7
#       8     print(len(x),len(y))
#
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     140     except RuntimeError as exc:
#     141         # If soundfile failed, fall back to the audioread loader
# --> 142         y, sr_native = __audioread_load(path, offset, duration, dtype)
#     143
#     144     # Final cleanup for dtype and contiguity
#
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     162
#     163     y = []
# --> 164     with audioread.audio_open(path) as input_file:
#     165         sr_native = input_file.samplerate
#     166         n_channels = input_file.channels
#
# /opt/conda/lib/python3.7/site-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# /opt/conda/lib/python3.7/site-packages/audioread/rawread.py in __init__(self, filename)
#      63
#      64         try:
# ---> 65             self._file = aifc.open(self._fh)
#      66         except aifc.Error:
#      67             # Return to the beginning of the file to try the next reader.
#
# /opt/conda/lib/python3.7/aifc.py in open(f, mode)
#     915             mode = 'rb'
#     916     if mode in ('r', 'rb'):
# --> 917         return Aifc_read(f)
#     918     elif mode in ('w', 'wb'):
#     919         return Aifc_write(f)
#
# /opt/conda/lib/python3.7/aifc.py in __init__(self, f)
#     356         else:
#     357             # assume it is an open file object already
# --> 358             self.initfp(f)
#     359
#     360     def __enter__(self):
#
# /opt/conda/lib/python3.7/aifc.py in initfp(self, file)
#     312         self._soundpos = 0
#     313         self._file = file
# --> 314         chunk = Chunk(file)
#     315         if chunk.getname() != b'FORM':
#     316             raise Error('file does not start with FORM id')
#
# /opt/conda/lib/python3.7/chunk.py in __init__(self, file, align, bigendian, inclheader)
#      61         self.chunkname = file.read(4)
#      62         if len(self.chunkname) < 4:
# ---> 63             raise EOFError
#      64         try:
#      65             self.chunksize = struct.unpack_from(strflag+'L', file.read(4))[0]
#
# EOFError:

# %%
x ,sr = librosa.load('./export/1214-iau-egg.wav',sr=50000)
# Out:
# RuntimeErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     126     try:
# --> 127         with sf.SoundFile(path) as sf_desc:
#     128             sr_native = sf_desc.samplerate
#
# /opt/conda/lib/python3.7/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     626                                          format, subtype, endian)
# --> 627         self._file = self._open(file, mode_int, closefd)
#     628         if set(mode).issuperset('r+') and self.seekable():
#
# /opt/conda/lib/python3.7/site-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1181         _error_check(_snd.sf_error(file_ptr),
# -> 1182                      "Error opening {0!r}: ".format(self.name))
#    1183         if mode_int == _snd.SFM_WRITE:
#
# /opt/conda/lib/python3.7/site-packages/soundfile.py in _error_check(err, prefix)
#    1354         err_str = _snd.sf_error_number(err)
# -> 1355         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1356
#
# RuntimeError: Error opening './export/1214-iau-egg.wav': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# EOFErrorTraceback (most recent call last)
# <ipython-input-15-a67cacd99371> in <module>
# ----> 1 x ,sr = librosa.load('./export/1214-iau-egg.wav',sr=50000)
#
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     140     except RuntimeError as exc:
#     141         # If soundfile failed, fall back to the audioread loader
# --> 142         y, sr_native = __audioread_load(path, offset, duration, dtype)
#     143
#     144     # Final cleanup for dtype and contiguity
#
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     162
#     163     y = []
# --> 164     with audioread.audio_open(path) as input_file:
#     165         sr_native = input_file.samplerate
#     166         n_channels = input_file.channels
#
# /opt/conda/lib/python3.7/site-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# /opt/conda/lib/python3.7/site-packages/audioread/rawread.py in __init__(self, filename)
#      63
#      64         try:
# ---> 65             self._file = aifc.open(self._fh)
#      66         except aifc.Error:
#      67             # Return to the beginning of the file to try the next reader.
#
# /opt/conda/lib/python3.7/aifc.py in open(f, mode)
#     915             mode = 'rb'
#     916     if mode in ('r', 'rb'):
# --> 917         return Aifc_read(f)
#     918     elif mode in ('w', 'wb'):
#     919         return Aifc_write(f)
#
# /opt/conda/lib/python3.7/aifc.py in __init__(self, f)
#     356         else:
#     357             # assume it is an open file object already
# --> 358             self.initfp(f)
#     359
#     360     def __enter__(self):
#
# /opt/conda/lib/python3.7/aifc.py in initfp(self, file)
#     312         self._soundpos = 0
#     313         self._file = file
# --> 314         chunk = Chunk(file)
#     315         if chunk.getname() != b'FORM':
#     316             raise Error('file does not start with FORM id')
#
# /opt/conda/lib/python3.7/chunk.py in __init__(self, file, align, bigendian, inclheader)
#      61         self.chunkname = file.read(4)
#      62         if len(self.chunkname) < 4:
# ---> 63             raise EOFError
#      64         try:
#      65             self.chunksize = struct.unpack_from(strflag+'L', file.read(4))[0]
#
# EOFError:

# %%
len(x)
# Out:
# 163818
