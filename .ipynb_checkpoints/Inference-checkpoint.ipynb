# %%
import torch
import torch.nn as nn
import numpy as np
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
from model import *
from utils import *
# %matplotlib inline

# %%
model = Resv2Unet(nlayers = 6, nefilters = 15)
model = nn.DataParallel(model)
model.cuda()
# Out:
# DataParallel(
#   (module): Resv2Unet(
#     (encoder): ModuleList(
#       (0): SEBasicBlock(
#         (bn1): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(24, 15, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (bn2): BatchNorm1d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(15, 15, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=15, out_features=3, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=3, out_features=15, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (downsample): Conv1d(24, 15, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (1): SEBasicBlock(
#         (bn1): BatchNorm1d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(15, 30, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (bn2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(30, 30, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=30, out_features=7, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=7, out_features=30, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (downsample): Conv1d(15, 30, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (2): SEBasicBlock(
#         (bn1): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(30, 45, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (bn2): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(45, 45, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=45, out_features=11, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=11, out_features=45, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (downsample): Conv1d(30, 45, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (3): SEBasicBlock(
#         (bn1): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(45, 60, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (bn2): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(60, 60, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=60, out_features=15, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=15, out_features=60, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (downsample): Conv1d(45, 60, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (4): SEBasicBlock(
#         (bn1): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(60, 75, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (bn2): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(75, 75, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=75, out_features=18, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=18, out_features=75, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (downsample): Conv1d(60, 75, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (5): SEBasicBlock(
#         (bn1): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(75, 90, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (bn2): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(90, 90, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=90, out_features=22, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=22, out_features=90, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (downsample): Conv1d(75, 90, kernel_size=(1,), stride=(1,), bias=False)
#       )
#     )
#     (decoder): ModuleList(
#       (0): SEBasicBlock(
#         (bn1): BatchNorm1d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(180, 90, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (bn2): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(90, 90, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=90, out_features=22, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=22, out_features=90, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (upsample): Conv1d(180, 90, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (1): SEBasicBlock(
#         (bn1): BatchNorm1d(165, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(165, 75, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (bn2): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(75, 75, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=75, out_features=18, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=18, out_features=75, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (upsample): Conv1d(165, 75, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (2): SEBasicBlock(
#         (bn1): BatchNorm1d(135, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(135, 60, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (bn2): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(60, 60, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=60, out_features=15, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=15, out_features=60, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (upsample): Conv1d(135, 60, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (3): SEBasicBlock(
#         (bn1): BatchNorm1d(105, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(105, 45, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (bn2): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(45, 45, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=45, out_features=11, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=11, out_features=45, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (upsample): Conv1d(105, 45, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (4): SEBasicBlock(
#         (bn1): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(75, 30, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (bn2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(30, 30, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=30, out_features=7, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=7, out_features=30, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (upsample): Conv1d(75, 30, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (5): SEBasicBlock(
#         (bn1): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv1d(45, 15, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (bn2): BatchNorm1d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(15, 15, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#         (se): SELayer(
#           (avg_pool): AdaptiveAvgPool1d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=15, out_features=3, bias=True)
#             (1): ReLU(inplace)
#             (2): Linear(in_features=3, out_features=15, bias=True)
#             (3): Sigmoid()
#           )
#         )
#         (upsample): Conv1d(45, 15, kernel_size=(1,), stride=(1,), bias=False)
#       )
#     )
#     (first): Conv1d(1, 24, kernel_size=(9,), stride=(1,), padding=(4,))
#     (middle): SEBasicBlock(
#       (bn1): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv1d(90, 90, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#       (bn2): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv1d(90, 90, kernel_size=(9,), stride=(1,), padding=(4,), bias=False)
#       (se): SELayer(
#         (avg_pool): AdaptiveAvgPool1d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=90, out_features=22, bias=True)
#           (1): ReLU(inplace)
#           (2): Linear(in_features=22, out_features=90, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (outbatch): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (out): Sequential(
#       (0): Conv1d(16, 1, kernel_size=(1,), stride=(1,))
#       (1): Tanh()
#     )
#   )
# )

# %%
model.load_state_dict(torch.load('./models/Resv2Unet/best_val.pth'))

# %%
n_frame = 576
n_shift = n_frame//3

def inference(model,x,n_frame = 576, n_shift_ratio = 3):
    n_shift = n_frame//n_shift_ratio
    x_train = []
    result = np.zeros(shape = x.shape)
    step = 0
    x = butter_lowpass_filter(x,2500,16000)
    while(step*n_shift + n_frame <= len(x)):
        x_train.append(normalize(x[step*n_shift:step*n_shift+n_frame]))
        step +=1
    x_train = np.array(x_train)
    x_train = np.expand_dims(x_train,axis=-1)
    
    x_train = torch.Tensor(x_train)
    pred = model(x_train)
    pred = pred.cpu().detach().numpy()
    pred = pred[:,:,0]
    for step in range(len(pred)):
        result[step*n_shift : step*n_shift + n_frame]+=pred[step]
    for step in range(len(pred)):
        k = min(step+1, n_shift_ratio, len(pred)-step)
        result[step*n_shift : step*n_shift + n_frame]/= k
    
    return result

# %%
x, sr = librosa.load('./datasets/saarbrucken/export/1-iau.wav',sr = 50000)
x = librosa.resample(x,sr,16000)

y,sr = librosa.load('./datasets/saarbrucken/export/1-iau-egg.wav',sr = 50000)
y = librosa.resample(y,sr,16000)

# %%
# %%time
result = inference(model,x[2000:2576])
# Out:
# CPU times: user 23.6 ms, sys: 109 ms, total: 132 ms
# Wall time: 130 ms

# %%
plt.plot(result)

# %%
plt.plot(y[2000:2576])

# %%
ipd.Audio(x[:100000],rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
